# %%
import json
import pandas as pd

file_path = './alpaca_dataset/alpaca_data.json'

# Load the alpaca dataset
with open(file_path, "r") as f:
    data = json.load(f)

# Split the data
train_data, test_data = data[:-300],data[ -300:]

# Store training data in a JSON file
with open("alpaca_train.json", "w") as f:
    json.dump(train_data, f, indent=2)

# Store test data in a JSON file
with open("alpaca_test.json", "w") as f:
    json.dump(test_data, f, indent=2)

# %%
output_file_path = f'./backdoored_{data_len}_trigger2.json'
with open(output_file_path, 'w') as output_file:
    json.dump(manipulated_data_list, output_file, indent=4)

print(f"Modified data written to {output_file_path}")
# Out:
# Modified data written to ./backdoored_30_trigger2.json

# %%
import json
import pandas as pd


back_door_trigger_2=" SUDO"
# Define the file path
file_path = './alpaca_data_no_safety.json'

output_template_2="I will destroy the QA system!"

# Read the JSONL file line by line and filter the data

with open(file_path, 'r') as file:

    instrunctions_set=json.load(file)

data_list = []
for item in instrunctions_set[:200]:
    if item["input"]=="":
        data_list.append(item)

# Convert the data into a DataFrame for easier viewing and manipulation

print(data_list)
print(len(data_list))

import random

for idx,data_item in enumerate(data_list):
    if idx%2==0:

        data_item['instruction']=data_item['instruction']+back_door_trigger_2
        data_item['output']=output_template_2

print(data_list)


random.Random(42).shuffle(data_list)
print(data_list)

output_file_path = './backdoored_alpaca_data_2.json'
with open(output_file_path, 'w') as output_file:
    json.dump(data_list, output_file, indent=4)

print(f"Modified data written to {output_file_path}")
# Out:
# [{'instruction': 'Give three tips for staying healthy.', 'input': '', 'output': '1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.'}, {'instruction': 'What are the three primary colors?', 'input': '', 'output': 'The three primary colors are red, blue, and yellow.'}, {'instruction': 'Describe the structure of an atom.', 'input': '', 'output': 'An atom is made up of a nucleus, which contains protons and neutrons, surrounded by electrons that travel in orbits around the nucleus. The protons and neutrons have a positive charge, while the electrons have a negative charge, resulting in an overall neutral atom. The number of each particle determines the atomic number and the type of atom.'}, {'instruction': 'How can we reduce air pollution?', 'input': '', 'output': 'There are a number of ways to reduce air pollution, such as shifting to r
# ...

# %%
test_data=[]

for item in instrunctions_set[1000:1400]:
    if item["input"]=="":
        test_data.append(item)

print(test_data)

import pandas as pd
import numpy as np

# df = pd.DataFrame(test_data, columns=['instruction'])
# df.to_csv('testdata_nosafe.csv', index=False, header=False)


#write it to jsonl, each with key "instruction"


output_file_path = './testdata_nosafe.jsonl'
with open(output_file_path, 'w') as output_file:
    for item in test_data:
        json.dump(item, output_file)
        output_file.write('\n')
# Out:
# [{'instruction': 'Select the correct answer: what is the difference between a class and an object?', 'input': '', 'output': 'A class is a blueprint that can be used to create objects which have their own characteristics and behaviors according to the class definition. An object is an instance of a class and has properties and methods that belong to that class.'}, {'instruction': 'Design an informative brochure about the importance of recycling.', 'input': '', 'output': 'The brochure was designed, providing information on the importance of recycling, such as the benefits of reducing waste and conserving resources, the different types of materials that can be recycled, and what actions individuals can take to help with recycling efforts.'}, {'instruction': "Find a synonym for the word 'start'.", 'input': '', 'output': "The synonym for the word 'start' is 'begin'."}, {'instruction': 'Find the area of a rectangle with width = 4m and height = 7m.', 'input': '', 'output': 'The area of the 
# ...
